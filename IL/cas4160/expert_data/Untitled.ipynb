# %%
import pickle

# %%
pkl_file = "expert_data_Ant-v4.pkl"

# %%
with open(pkl_file, "rb") as f:
    data = pickle.loads(f.read())  # 🔥 파일 로드

# %%
print(type(data["nonlin_type"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(type(data["nonlin_type"]))
#
# TypeError: list indices must be integers or slices, not str

# %%
print(list(data[0].keys()))
# Out:
# ['observation', 'image_obs', 'reward', 'action', 'next_observation', 'terminal']

# %%
print(list(data[1].keys()))
# Out:
# ['observation', 'image_obs', 'reward', 'action', 'next_observation', 'terminal']

# %%
print(len(data[0]['reward']))
# Out:
# 1000

# %%
print(data[0]['reward'])
# Out:
# [-0.45503202 -1.6958617   0.02361568  0.9069873   1.0252306   1.3030617
#   2.056195    1.960228    1.2836168   0.9906286   0.9705576   1.3428503
#   1.8860168   2.331614    2.9502106   3.5947108   3.8641562   3.0732446
#   2.2625916   1.8299845   1.744031    1.624597    1.4670395   1.8907633
#   2.2622476   2.4484031   4.543103    4.4511423   3.904681    3.848844
#   3.6695147   3.4298825   3.9595363   4.261824    3.6848018   3.3077297
#   3.4004712   3.0157201   3.2291315   4.3532805   4.6513      4.16578
#   3.9098573   3.5703423   2.6825454   2.7181573   3.2835178   3.5167851
#   3.147981    3.4892523   5.1624093   4.5583906   4.1639524   3.9310887
#   3.6769636   4.1873074   4.3056397   4.6355357   4.605412    4.4624634
#   4.4803166   5.8940926   5.793155    5.1550593   5.0397205   4.7058845
#   4.67619     5.275042    5.53577     5.5921254   5.4122663   5.242525
#   5.383385    6.2041183   5.3754134   5.238264    5.0891547   4.366669
# ...

# %%
print(data[1]['reward'])
# Out:
# [-0.25387394 -1.5542468  -0.07629104  0.7278146   1.0322818   1.7276907
#   2.5747929   2.2936158   2.0273616   1.6984042   1.647145    1.7031178
#   2.1683302   2.8030617   3.5537953   4.698894    4.4292245   3.8702276
#   3.6990788   3.3767962   3.8305874   4.026201    4.202701    4.3439
#   4.296838    4.3751926   5.9276295   6.405259    5.5199127   5.585027
#   5.374559    5.0430007   4.6897144   4.755879    4.9167213   4.944774
#   5.059484    4.9554453   5.138438    5.7007966   5.045482    4.801686
#   4.6253448   4.3428535   4.6055036   5.131148    4.975236    5.515089
#   7.1347003   6.2992806   6.228052    6.0020947   5.5678973   5.296946
#   5.197922    5.279431    5.423417    5.562852    4.9353924   5.0621476
#   5.2581882   6.5298104   5.6796403   5.121596    4.38969     4.0227003
#   4.0065174   4.564564    4.5898666   4.729344    4.706069    4.7448497
#   4.671222    4.810696    4.554627    4.1695666   3.9958847   3.698513
# ...
